# %%
# !pip3 install torch==1.8.2+cpu torchvision==0.9.2+cpu torchaudio==0.8.2 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Out:
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Collecting torch==1.8.2+cpu
#   Downloading https://download.pytorch.org/whl/lts/1.8/cpu/torch-1.8.2%2Bcpu-cp39-cp39-linux_x86_64.whl (169.1 MB)
#      |████████████████████████████████| 169.1 MB 8.3 MB/s eta 0:00:01
# Collecting torchvision==0.9.2+cpu
#   Downloading https://download.pytorch.org/whl/lts/1.8/cpu/torchvision-0.9.2%2Bcpu-cp39-cp39-linux_x86_64.whl (13.3 MB)
#      |████████████████████████████████| 13.3 MB 896 kB/s eta 0:00:01
# Collecting torchaudio==0.8.2
#   Downloading https://download.pytorch.org/whl/lts/1.8/torchaudio-0.8.2-cp39-cp39-linux_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 166 kB/s eta 0:00:01
# Requirement already satisfied: numpy in /home/naitik/.local/lib/python3.9/site-packages (from torch==1.8.2+cpu) (1.19.5)
# Requirement already satisfied: typing-extensions in /home/naitik/.local/lib/python3.9/site-packages (from torch==1.8.2+cpu) (3.7.4.3)
# Requirement already satisfied: pillow>=4.1.1 in /usr/lib/python3/dist-packages (from torchvision==0.9.2+cpu) (8.1.2)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-1.8.2+cpu torchaudio-0.8.2 torchvision-0.9.2+cpu

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.9.2-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 7.9 MB/s eta 0:00:01
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 5.6 MB/s eta 0:00:01
# Collecting huggingface-hub==0.0.12
#   Downloading huggingface_hub-0.0.12-py3-none-any.whl (37 kB)
# Requirement already satisfied: packaging in /home/naitik/.local/lib/python3.9/site-packages (from transformers) (20.9)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from transformers) (2.25.1)
# Collecting filelock
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers) (5.3.1)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 4.6 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17 in /home/naitik/.local/lib/python3.9/site-packages (from transformers) (1.19.5)
# Requirement already satisfied: tqdm>=4.27 in /home/naitik/.local/lib/python3.9/site-packages (from transformers) (4.61.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/naitik/.local/lib/python3.9/site-packages (from transformers) (2021.7.1)
# Requirement already satisfied: typing-extensions in /home/naitik/.local/lib/python3.9/site-packages (from huggingface-hub==0.0.12->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/naitik/.local/lib/python3.9/site-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: joblib in /home/naitik/.local/lib/python3.9/site-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from sacremoses->transformers) (1.15.0)
# Installing collected packages: filelock, tokenizers, sacremoses, huggingface-hub, transformers
# Successfully installed filelock-3.0.12 huggingface-hub-0.0.12 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.9.2

# %%
from transformers import PegasusForConditionalGeneration, PegasusTokenizer
# Out:
# 2021-08-26 15:44:28.141091: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-08-26 15:44:28.141130: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# first run this command in your terminal - pip install sentencepiece

tokenizer = PegasusTokenizer.from_pretrained("google/pegasus-xsum")

# %%
# Out:
# Downloading:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.28G [00:00<?, ?B/s]

# %%
https://www.youtube.com/watch?v=Yo5Hw8aV3vY&t=669s
